# %% [markdown]
# ## Lab 03.01 - Introduction to Pandas and Data Operations
# Welcome to your first exploration of data analysis with Python! In this lab, you'll learn how to use the pandas library to analyze real-world sales data. By the end of this lab, you'll be comfortable with the fundamental operations in pandas.
